# %%
import pandas as pd
import numpy as np
import missingno as msno

# %%
# %matplotlib inline

# %%
covid_cases = pd.read_csv("counties.csv")
df_covid_cases_1 = covid_cases.iloc[:,:10]
df_covid_cases_2 = covid_cases.iloc[:,10:20]
df_covid_cases_3 = covid_cases.iloc[:,20:]

# %%
#df_covid_cases_1

# %%
#df_covid_cases_2

# %%
#df_covid_cases_3

# %%
msno.matrix(df_covid_cases_1.sample(2000))

# %%
msno.matrix(df_covid_cases_2.sample(2000))

# %%
msno.matrix(df_covid_cases_3.sample(2000))

# %%
msno.bar(covid_cases.sample(1000))

# %%
msno.heatmap(covid_cases)

# %%
msno.dendrogram(covid_cases)
