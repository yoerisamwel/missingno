# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data_set = pd.read_csv("SFO_Airport_Utility_Consumption.csv")

# %%
msno.matrix(data_set.sample(250))

# %%
msno.bar(data_set.sample(560))
